# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
# generate data like sin curve
def generate_data(n, sigma):
    x = np.random.uniform(-1, 1, n)
    y = np.sin(2 * np.pi * x) + np.random.normal(0, sigma, n)
    return x, y

train_data = generate_data(50, 0.3)
test_data = generate_data(30, 0.3)
plt.scatter(train_data[0], train_data[1], c='tab:blue', label='train data')
plt.scatter(test_data[0], test_data[1], c='tab:orange', label='test data')

x = np.linspace(-1, 1, 100)
y = np.sin(2 * np.pi * x)
plt.plot(x, y, c='tab:green', label='sin curve')
plt.legend()
plt.show()

# %%
degree = 100000  # 多項式の次数
poly_features = PolynomialFeatures(degree=degree)
x_poly = poly_features.fit_transform(train_data[0].reshape(-1, 1))

model = LinearRegression()
model.fit(x_poly, train_data[1])

new_x = np.linspace(-1, 1, 1000)
new_x_poly = poly_features.transform(new_x.reshape(-1, 1))
predictions = model.predict(new_x_poly)

plt.scatter(train_data[0], train_data[1], c='tab:blue', label='train data')
plt.plot(new_x[200:800], predictions[200:800], c='tab:orange', label='prediction')
plt.plot(x, y, c='tab:green', label='sin curve')
plt.legend()
plt.show()

# %%
# svd to train data
u, s, vh = np.linalg.svd(np.array(train_data), full_matrices=False)
s.shape
# Out:
# (2,)

# %%
np.array(train_data).shape
# Out:
# (2, 50)
